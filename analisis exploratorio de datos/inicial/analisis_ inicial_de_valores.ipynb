# %% [markdown]
# ## __TRABAJO PRÁCTICO 1__: *Análisis inicial de valores*

# %% [markdown]
# ### Análisis realizados
# - [df_train_values](#link_1)
# - [df_train_labels](#link_2)
# - [Análisis de valores por columna](#link_3)
#      - [building_id](#link_4)
#      - [geo_level](#link_5)
#      - [count_floors_pre_eq](#link_6)
#      - [age](#link_7)
#      - [area_percentage](#link_8)
#      - [height_percentage](#link_9)
#      - [land_surface_condition](#link_10)
#      - [foundation_type](#link_11)
#      - [roof_type](#link_12)
#      - [ground_floor_type](#link_13)
#      - [other_floor_type](#link_14)
#      - [position](#link_15)
#      - [has_superstructure..](#link_16)
#      - [legal_ownership_status](#link_17)
#      - [count_families](#link_18)
#      - [has_secondary..](#link_19)
#      - [damage_grade](#link_20)
# - [Merge de los DataFrames](#link_21)
# - [Relaciones interesante entre features](#link_22)

# %% [markdown]
# ### Importamos las librerías

# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importamos los datos

# %%
df_train_values = pd.read_csv('../datasets/train_values.csv')
df_train_labels = pd.read_csv('../datasets/train_labels.csv')

# %% [markdown]
# ### **df_train_values**<a id='link_1'></a>

# %%
df_train_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
#  10  roof_type                               260601 non-null  object
#  11  ground_floor_type                       260601 non-null  object
#  12  other_floor_type                        260601 non-null  object
#  13  position                                260601 non-null  object
#  14  plan_configuration                      260601 non-null  object
#  15  has_superstructure_adobe_mud            260601 non-null  int64
#  16  has_superstructure_mud_mortar_stone     260601 non-null  int64
#  17  has_superstructure_stone_flag           260601 non-null  int64
#  18  has_superstructure_cement_mortar_stone  260601 non-null  int64
#  19  has_superstructure_mud_mortar_brick     260601 non-null  int64
#  20  has_superstructure_cement_mortar_brick  260601 non-null  int64
#  21  has_superstructure_timber               260601 non-null  int64
#  22  has_superstructure_bamboo               260601 non-null  int64
#  23  has_superstructure_rc_non_engineered    260601 non-null  int64
#  24  has_superstructure_rc_engineered        260601 non-null  int64
#  25  has_superstructure_other                260601 non-null  int64
#  26  legal_ownership_status                  260601 non-null  object
#  27  count_families                          260601 non-null  int64
#  28  has_secondary_use                       260601 non-null  int64
#  29  has_secondary_use_agriculture           260601 non-null  int64
#  30  has_secondary_use_hotel                 260601 non-null  int64
#  31  has_secondary_use_rental                260601 non-null  int64
#  32  has_secondary_use_institution           260601 non-null  int64
#  33  has_secondary_use_school                260601 non-null  int64
#  34  has_secondary_use_industry              260601 non-null  int64
#  35  has_secondary_use_health_post           260601 non-null  int64
#  36  has_secondary_use_gov_office            260601 non-null  int64
#  37  has_secondary_use_use_police            260601 non-null  int64
#  38  has_secondary_use_other                 260601 non-null  int64
# dtypes: int64(31), object(8)
# memory usage: 77.5+ MB

# %%
df_train_values.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# #### **#** df_train_values no tiene valores nulos.

# %% [markdown]
# #### Cambiamos los tipos categóricos y booleanos

# %%
df_train_values=df_train_values.astype({
                        'land_surface_condition':'category',
                        'foundation_type':'category',
                        'roof_type':'category',
                        'ground_floor_type':'category',
                        'other_floor_type':'category',
                        'position':'category',
                        'plan_configuration':'category',
    
                        'has_superstructure_adobe_mud':'bool',
                        'has_superstructure_mud_mortar_stone':'bool',
                        'has_superstructure_stone_flag':'bool',
                        'has_superstructure_cement_mortar_stone':'bool', 
                        'has_superstructure_mud_mortar_brick':'bool', 
                        'has_superstructure_cement_mortar_brick':'bool', 
                        'has_superstructure_timber':'bool', 
                        'has_superstructure_bamboo':'bool', 
                        'has_superstructure_rc_non_engineered':'bool', 
                        'has_superstructure_rc_engineered':'bool', 
                        'has_superstructure_other':'bool',
                        
                        'legal_ownership_status':'category',

                        'has_secondary_use':'bool',
                        'has_secondary_use_agriculture':'bool', 
                        'has_secondary_use_hotel':'bool', 
                        'has_secondary_use_rental':'bool', 
                        'has_secondary_use_institution':'bool', 
                        'has_secondary_use_school':'bool',
                        'has_secondary_use_industry':'bool',
                        'has_secondary_use_health_post':'bool',
                        'has_secondary_use_gov_office':'bool',
                        'has_secondary_use_use_police':'bool',
                        'has_secondary_use_other':'bool'})

# %%
df_train_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  category
#  9   foundation_type                         260601 non-null  category
#  10  roof_type                               260601 non-null  category
#  11  ground_floor_type                       260601 non-null  category
#  12  other_floor_type                        260601 non-null  category
#  13  position                                260601 non-null  category
#  14  plan_configuration                      260601 non-null  category
#  15  has_superstructure_adobe_mud            260601 non-null  bool
#  16  has_superstructure_mud_mortar_stone     260601 non-null  bool
#  17  has_superstructure_stone_flag           260601 non-null  bool
#  18  has_superstructure_cement_mortar_stone  260601 non-null  bool
#  19  has_superstructure_mud_mortar_brick     260601 non-null  bool
#  20  has_superstructure_cement_mortar_brick  260601 non-null  bool
#  21  has_superstructure_timber               260601 non-null  bool
#  22  has_superstructure_bamboo               260601 non-null  bool
#  23  has_superstructure_rc_non_engineered    260601 non-null  bool
#  24  has_superstructure_rc_engineered        260601 non-null  bool
#  25  has_superstructure_other                260601 non-null  bool
#  26  legal_ownership_status                  260601 non-null  category
#  27  count_families                          260601 non-null  int64
#  28  has_secondary_use                       260601 non-null  bool
#  29  has_secondary_use_agriculture           260601 non-null  bool
#  30  has_secondary_use_hotel                 260601 non-null  bool
#  31  has_secondary_use_rental                260601 non-null  bool
#  32  has_secondary_use_institution           260601 non-null  bool
#  33  has_secondary_use_school                260601 non-null  bool
#  34  has_secondary_use_industry              260601 non-null  bool
#  35  has_secondary_use_health_post           260601 non-null  bool
#  36  has_secondary_use_gov_office            260601 non-null  bool
#  37  has_secondary_use_use_police            260601 non-null  bool
#  38  has_secondary_use_other                 260601 non-null  bool
# dtypes: bool(22), category(8), int64(9)
# memory usage: 25.4 MB

# %% [markdown]
# #### Uso de memoria (df_train_values)

# %%
1 - (25.4 / 77.5)
# Out:
# 0.6722580645161291

# %% [markdown]
# #### **#** Con los cambios de tipos de datos el uso de memoria se redujo un 67%.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **df_train_labels**<a id='link_2'></a>

# %%
df_train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   building_id   260601 non-null  int64
#  1   damage_grade  260601 non-null  int64
# dtypes: int64(2)
# memory usage: 4.0 MB

# %%
df_train_labels.shape
# Out:
# (260601, 2)

# %% [markdown]
# #### **#** df_train_labels no tiene valores nulos.

# %%
df_train_labels = df_train_labels.astype({'damage_grade':'category'})

# %%
df_train_labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 2 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   building_id   260601 non-null  int64
#  1   damage_grade  260601 non-null  category
# dtypes: category(1), int64(1)
# memory usage: 2.2 MB

# %% [markdown]
# #### Uso de memoria (df_train_labels)

# %%
1 - (2.2 / 4)
# Out:
# 0.44999999999999996

# %% [markdown]
# #### **#** Con los cambios de tipos de datos el uso de memoria se redujo un 45%

# %% [markdown]
# #### Uso de memoria total

# %%
1-((25.4 + 2.2)/ (77.5 + 4))
# Out:
# 0.6613496932515337

# %% [markdown]
# #### **#** Ahorro de memoría = 66%

# %%
(25.4 + 2.2)/ (77.5 + 4)
# Out:
# 0.33865030674846625

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Análisis de valores por columna**<a id='link_3'></a>

# %% [markdown]
# #### **building_id**<a id='link_4'></a>

# %%
df_train_values['building_id'].value_counts().sum()
# Out:
# 260601

# %%
df_train_values['building_id'].max()
# Out:
# 1052934

# %%
df_train_values['building_id'].min()
# Out:
# 4

# %% [markdown]
# **building_id:** no hay valores de building_id repetidos.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **geo_level**<a id='link_5'></a>

# %%
df_train_values['geo_level_1_id'].min()
# Out:
# 0

# %%
df_train_values['geo_level_1_id'].max()
# Out:
# 30

# %%
df_train_values['geo_level_2_id'].min()
# Out:
# 0

# %%
df_train_values['geo_level_2_id'].max()
# Out:
# 1427

# %%
df_train_values['geo_level_3_id'].min()
# Out:
# 0

# %%
df_train_values['geo_level_3_id'].max()
# Out:
# 12567

# %%
df_train_values['geo_level_3_id'].value_counts()
# Out:
# 633      651
# 9133     647
# 621      530
# 11246    470
# 2005     466
#         ...
# 6095       1
# 3599       1
# 7886       1
# 9994       1
# 11851      1
# Name: geo_level_3_id, Length: 11595, dtype: int64

# %% [markdown]
# **geo_level:** los valores coinciden con los detallados en el enunciado.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **count_floors_pre_eq**<a id='link_6'></a>

# %%
df_train_values['count_floors_pre_eq'].describe()
# Out:
# count             260,601.00
# mean                    2.13
# std                     0.73
# min                     1.00
# 25%                     2.00
# 50%                     2.00
# 75%                     2.00
# max                     9.00
# Name: count_floors_pre_eq, dtype: float64

# %%
df_train_values['count_floors_pre_eq'].value_counts(normalize='true')
# Out:
# 2                   0.60
# 3                   0.21
# 1                   0.16
# 4                   0.02
# 5                   0.01
# 6                   0.00
# 7                   0.00
# 9                   0.00
# 8                   0.00
# Name: count_floors_pre_eq, dtype: float64

# %%
df_train_values['count_floors_pre_eq'].value_counts().iloc[0:3,].sum()/260601
# Out:
# 0.9696087121691782

# %%
df_train_values['count_floors_pre_eq'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Cantidad de pisos antes del terremoto',color='brown');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('count_floors_pre_eq')
plt.tick_params(labelsize=10)

# %% [markdown]
# **count_floors_pre_eq:** la gran mayoría de los edificios eran de 2 pisos, y en general era una ciudad de edificaciones bajas, el 97% no superaba los 3 pisos.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ####  **age**<a id='link_7'></a>

# %%
df_train_values['age'].describe()
# Out:
# count             260,601.00
# mean                   26.54
# std                    73.57
# min                     0.00
# 25%                    10.00
# 50%                    15.00
# 75%                    30.00
# max                   995.00
# Name: age, dtype: float64

# %%
df_train_values['age'].value_counts(normalize='true')
# Out:
# 10                    0.15
# 15                    0.14
# 5                     0.13
# 20                    0.12
# 0                     0.10
# 25                    0.09
# 30                    0.07
# 35                    0.04
# 40                    0.04
# 50                    0.03
# 45                    0.02
# 60                    0.01
# 80                    0.01
# 55                    0.01
# 70                    0.01
# 995                   0.01
# 100                   0.01
# 65                    0.00
# 90                    0.00
# 85                    0.00
# 75                    0.00
# 95                    0.00
# 120                   0.00
# 150                   0.00
# 200                   0.00
# 110                   0.00
# 105                   0.00
# 125                   0.00
# 115                   0.00
# 140                   0.00
# 130                   0.00
# 180                   0.00
# 160                   0.00
# 170                   0.00
# 175                   0.00
# 135                   0.00
# 145                   0.00
# 190                   0.00
# 195                   0.00
# 165                   0.00
# 155                   0.00
# 185                   0.00
# Name: age, dtype: float64

# %%
df_train_values['age'].value_counts().iloc[0:9,].sum()/260601
# Out:
# 0.8844517097018046

# %%
sns.distplot(df_train_values['age'], hist=True, kde=True,
             bins=int(180/5), color = 'orange', 
             hist_kws={'edgecolor':'grey'},
             kde_kws={'linewidth': 4})

plt.xlabel('Age',fontsize=24)
plt.ylabel('Edificios',fontsize=24)
plt.title('Antigüedad de los edificios',fontsize=28)
plt.tick_params(labelsize=20)

# %%
1390/260601
# Out:
# 0.0053338245056619125

# %%
df_train_values['age_sin_995']=df_train_values.loc[df_train_values['age']<995,'age']

# %%
sns.distplot(df_train_values['age_sin_995'], hist=True, kde=True,
             bins=int(180/5), color = 'orange', 
             hist_kws={'edgecolor':'grey'},
             kde_kws={'linewidth': 4})

plt.xlabel('Age',fontsize=24)
plt.ylabel('Edificios',fontsize=24)
plt.title('Antigüedad de los edificios - antigüedad < 995',fontsize=28)
plt.tick_params(labelsize=20)

# %% [markdown]
# **age:** el 88% de los edificios tenia cuarenta años o menos.
# **Observación:** hay 1.390 edificios con una antiguedad cercana a 1.000 años, cuando el resto no supera los 200 años de antiguedad.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **area_percentage**<a id='link_8'></a>

# %%
df_train_values['area_percentage'].describe()
# Out:
# count             260,601.00
# mean                    8.02
# std                     4.39
# min                     1.00
# 25%                     5.00
# 50%                     7.00
# 75%                     9.00
# max                   100.00
# Name: area_percentage, dtype: float64

# %%
df_train_values['area_percentage'].value_counts(normalize='true').head(20)
# Out:
# 6                    0.16
# 7                    0.14
# 5                    0.13
# 8                    0.11
# 9                    0.09
# 4                    0.07
# 10                   0.06
# 11                   0.05
# 3                    0.05
# 12                   0.03
# 13                   0.02
# 14                   0.02
# 15                   0.01
# 2                    0.01
# 16                   0.01
# 17                   0.01
# 19                   0.01
# 18                   0.01
# 20                   0.00
# 23                   0.00
# Name: area_percentage, dtype: float64

# %%
df_train_values['area_percentage'].value_counts().iloc[0:10,].sum()/260601
# Out:
# 0.8837533240471065

# %%
sns.distplot(df_train_values['area_percentage'], hist=True, kde=True, 
             bins=int(180/5), color = 'Green', 
             hist_kws={'edgecolor':'grey'},
             kde_kws={'linewidth': 4})

plt.xlabel('area_percentage',fontsize=24)
plt.ylabel('Edificios',fontsize=24)
plt.title('Porcentaje de superficie ocupada por los edificios',fontsize=28)
plt.tick_params(labelsize=20)

# %% [markdown]
# **area_percentage:** el 88% de los edificios ocupaba el 12% del area o menos.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **height_percentage**<a id='link_9'></a>

# %%
df_train_values['height_percentage'].describe()
# Out:
# count             260,601.00
# mean                    5.43
# std                     1.92
# min                     2.00
# 25%                     4.00
# 50%                     5.00
# 75%                     6.00
# max                    32.00
# Name: height_percentage, dtype: float64

# %%
df_train_values['height_percentage'].value_counts(normalize='true')
# Out:
# 5                    0.30
# 6                    0.18
# 4                    0.14
# 7                    0.14
# 3                    0.10
# 8                    0.05
# 2                    0.04
# 9                    0.02
# 10                   0.02
# 11                   0.00
# 12                   0.00
# 13                   0.00
# 15                   0.00
# 16                   0.00
# 32                   0.00
# 18                   0.00
# 14                   0.00
# 20                   0.00
# 21                   0.00
# 23                   0.00
# 17                   0.00
# 19                   0.00
# 24                   0.00
# 25                   0.00
# 26                   0.00
# 28                   0.00
# 31                   0.00
# Name: height_percentage, dtype: float64

# %%
df_train_values['height_percentage'].value_counts().iloc[0:9,].sum()/260601
# Out:
# 0.9871412619291561

# %%
sns.distplot(df_train_values['height_percentage'], hist=True, kde=True, 
             bins=int(180/5), color = 'Blue', 
             hist_kws={'edgecolor':'grey'},
             kde_kws={'linewidth': 4})

plt.xlabel('height_percentage',fontsize=24)
plt.ylabel('Edificios',fontsize=24)
plt.title('Porcnetaje de edificios por altura',fontsize=28)
plt.tick_params(labelsize=20)

# %% [markdown]
# **height_percentage:** el 99% de los edificios tenia menos de 10 mts. de altura, lo cual tiene sentido con la cantidad de pisos.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **land_surface_condition**<a id='link_10'></a>

# %%
df_train_values['land_surface_condition'].value_counts()
# Out:
# t    216757
# n     35528
# o      8316
# Name: land_surface_condition, dtype: int64

# %%
df_train_values['land_surface_condition'].value_counts(normalize='true')
# Out:
# t                   0.83
# n                   0.14
# o                   0.03
# Name: land_surface_condition, dtype: float64

# %%
df_train_values['land_surface_condition'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Condición de la superficie terrestre',color='peru')

ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('land_surface_condition')
plt.tick_params(labelsize=10)

# %% [markdown]
# **land_surface_condition:** hay una mayoría importante del valor **t** (83%), mientras que el menor es **o** (3%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **foundation_type**<a id='link_11'></a>

# %%
df_train_values['foundation_type'].value_counts()
# Out:
# r    219196
# w     15118
# u     14260
# i     10579
# h      1448
# Name: foundation_type, dtype: int64

# %%
df_train_values['foundation_type'].value_counts(normalize='true')
# Out:
# r                   0.84
# w                   0.06
# u                   0.05
# i                   0.04
# h                   0.01
# Name: foundation_type, dtype: float64

# %%
df_train_values['foundation_type'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Tipo de cimientos',color='dimgray');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('foundation_type')
plt.tick_params(labelsize=10)

# %% [markdown]
# **foundation_type:** hay una mayoría importante del valor **r** (84%), mientras que el menor es **h** (1%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **roof_type**<a id='link_12'></a>

# %%
df_train_values['roof_type'].value_counts()
# Out:
# n    182842
# q     61576
# x     16183
# Name: roof_type, dtype: int64

# %%
df_train_values['roof_type'].value_counts(normalize='true')
# Out:
# n                   0.70
# q                   0.24
# x                   0.06
# Name: roof_type, dtype: float64

# %%
df_train_values['roof_type'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Tipo de techo',color='indianred');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('roof_type')
plt.tick_params(labelsize=10)

# %% [markdown]
# **roof_type:** hay una mayoría del valor **n** (70%), mientras que el menor es **x** (6%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **ground_floor_type**<a id='link_13'></a>

# %%
df_train_values['ground_floor_type'].value_counts()
# Out:
# f    209619
# x     24877
# v     24593
# z      1004
# m       508
# Name: ground_floor_type, dtype: int64

# %%
df_train_values['ground_floor_type'].value_counts(normalize='true')
# Out:
# f                   0.80
# x                   0.10
# v                   0.09
# z                   0.00
# m                   0.00
# Name: ground_floor_type, dtype: float64

# %%
df_train_values['ground_floor_type'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Tipo de construcción usada en la planta baja',color='cadetblue');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('ground_floor_type')
plt.tick_params(labelsize=10)

# %% [markdown]
# **ground_floor_type:** hay una mayoría importante del valor **f** (80%), mientras que los menores son **z** y **m** (menos del 1%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **other_floor_type**<a id='link_14'></a>

# %%
df_train_values['other_floor_type'].value_counts()
# Out:
# q    165282
# x     43448
# j     39843
# s     12028
# Name: other_floor_type, dtype: int64

# %%
df_train_values['other_floor_type'].value_counts(normalize='true')
# Out:
# q                   0.63
# x                   0.17
# j                   0.15
# s                   0.05
# Name: other_floor_type, dtype: float64

# %%
df_train_values['other_floor_type'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Tipo de construcción usada en otros pisos',color='darksalmon');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('other_floor_type')
plt.tick_params(labelsize=10)

# %% [markdown]
# **other_floor_type:** hay una mayoría del valor **q** (63%), mientras que el menor es **s** (5%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **position**<a id='link_15'></a>

# %%
df_train_values['position'].value_counts()
# Out:
# s    202090
# t     42896
# j     13282
# o      2333
# Name: position, dtype: int64

# %%
df_train_values['position'].value_counts(normalize='true')
# Out:
# s                   0.78
# t                   0.16
# j                   0.05
# o                   0.01
# Name: position, dtype: float64

# %%
df_train_values['position'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Orientación del edificio',color='g');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('position')
plt.tick_params(labelsize=10)

# %% [markdown]
# **position:** hay una mayoría del valor **s** (78%), mientras que el menor es **o** (1%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **plan_configuration**<a id='link_15'></a>

# %%
df_train_values['plan_configuration'].value_counts()
# Out:
# d    250072
# q      5692
# u      3649
# s       346
# c       325
# a       252
# o       159
# m        46
# n        38
# f        22
# Name: plan_configuration, dtype: int64

# %%
df_train_values['plan_configuration'].value_counts(normalize='true')
# Out:
# d                   0.96
# q                   0.02
# u                   0.01
# s                   0.00
# c                   0.00
# a                   0.00
# o                   0.00
# m                   0.00
# n                   0.00
# f                   0.00
# Name: plan_configuration, dtype: float64

# %%
df_train_values['plan_configuration'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Construcción con diseño sísmico',color='slategray');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('plan_configuration')
plt.tick_params(labelsize=10)

# %% [markdown]
# **plan_configuration:** hay una mayoría importante del valor **d** (96%), mientras que la mayoria del resto de los valores no alcanza el 1%.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **has_superstructure**<a id='link_16'></a>

# %%
df_has_superstructure = df_train_values[[
                    'has_superstructure_adobe_mud',
                    'has_superstructure_mud_mortar_stone',
                    'has_superstructure_stone_flag',
                    'has_superstructure_cement_mortar_stone',
                    'has_superstructure_mud_mortar_brick',
                    'has_superstructure_cement_mortar_brick',
                    'has_superstructure_timber',
                    'has_superstructure_bamboo',
                    'has_superstructure_rc_non_engineered',
                    'has_superstructure_rc_engineered',
                    'has_superstructure_other'   ]]

# %%
df_has_superstructure.head()
# Out:
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                          True                                 True
# 1                         False                                 True
# 2                         False                                 True
# 3                         False                                 True
# 4                          True                                False
#
#    has_superstructure_stone_flag  has_superstructure_cement_mortar_stone  \
# 0                          False                                   False
# 1                          False                                   False
# 2                          False                                   False
# 3                          False                                   False
# 4                          False                                   False
#
#    has_superstructure_mud_mortar_brick  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    has_superstructure_cement_mortar_brick  has_superstructure_timber  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                       True
# 4                                   False                      False
#
#    has_superstructure_bamboo  has_superstructure_rc_non_engineered  \
# 0                      False                                 False
# 1                      False                                 False
# 2                      False                                 False
# 3                       True                                 False
# 4                      False                                 False
#
#    has_superstructure_rc_engineered  has_superstructure_other
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False

# %%
df_has_superstructure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 11 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   has_superstructure_adobe_mud            260601 non-null  bool
#  1   has_superstructure_mud_mortar_stone     260601 non-null  bool
#  2   has_superstructure_stone_flag           260601 non-null  bool
#  3   has_superstructure_cement_mortar_stone  260601 non-null  bool
#  4   has_superstructure_mud_mortar_brick     260601 non-null  bool
#  5   has_superstructure_cement_mortar_brick  260601 non-null  bool
#  6   has_superstructure_timber               260601 non-null  bool
#  7   has_superstructure_bamboo               260601 non-null  bool
#  8   has_superstructure_rc_non_engineered    260601 non-null  bool
#  9   has_superstructure_rc_engineered        260601 non-null  bool
#  10  has_superstructure_other                260601 non-null  bool
# dtypes: bool(11)
# memory usage: 2.7 MB

# %%
df_has_superstructure.sum()
# Out:
# has_superstructure_adobe_mud               23101
# has_superstructure_mud_mortar_stone       198561
# has_superstructure_stone_flag               8947
# has_superstructure_cement_mortar_stone      4752
# has_superstructure_mud_mortar_brick        17761
# has_superstructure_cement_mortar_brick     19615
# has_superstructure_timber                  66450
# has_superstructure_bamboo                  22154
# has_superstructure_rc_non_engineered       11099
# has_superstructure_rc_engineered            4133
# has_superstructure_other                    3905
# dtype: int64

# %%
df_has_superstructure.sum().plot(kind='bar',figsize=(8,4),
                            rot=90,title='Cantidad de edificios por tipo de superestructura',color='slategray');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('has_superstructure')
plt.tick_params(labelsize=10)

# %%
df_has_superstructure['has_superstructure_mud_mortar_stone'].sum()/260601
# Out:
# 0.7619349119918957

# %%
df_has_superstructure['has_superstructure_timber'].sum()/260601
# Out:
# 0.2549875096411756

# %%
df_has_superstructure['Suma_structure'] = df_has_superstructure.sum(axis=1)

# %%
df_has_superstructure['Suma_structure'].value_counts()
# Out:
# 1    176016
# 2     57838
# 3     20210
# 4      4925
# 5      1259
# 6       314
# 7        35
# 8         4
# Name: Suma_structure, dtype: int64

# %%
df_has_mas_superstruct=df_train_values[(df_has_superstructure['Suma_structure'] > 1)]

# %%
df_has_mas_superstruct
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 3            590882              22             418           10694
# 7            475515              20             323           12236
# 8            441126               0             757            7219
# 10             7962              17            1119           12188
# ...             ...             ...             ...             ...
# 260583       192421               7             322            2843
# 260585       722577               6             744           10556
# 260587       603159               8             696            4513
# 260590       695987              20             922           10283
# 260592       207683              10            1382            1903
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# 3                         2   10                6                  5
# 7                         2    0                8                  6
# 8                         2   15                8                  6
# 10                        2   20                9                  6
# ...                     ...  ...              ...                ...
# 260583                    2   10                6                  6
# 260585                    2   45               17                  5
# 260587                    3   20                7                  9
# 260590                    2    5                7                  5
# 260592                    2   25                5                  5
#
#        land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 0                           t               r  ...                   False
# 3                           t               r  ...                   False
# 7                           t               w  ...                   False
# 8                           t               r  ...                   False
# 10                          t               r  ...                   False
# ...                       ...             ...  ...                     ...
# 260583                      t               r  ...                   False
# 260585                      t               r  ...                   False
# 260587                      t               r  ...                   False
# 260590                      t               r  ...                   False
# 260592                      t               r  ...                   False
#
#        has_secondary_use_rental has_secondary_use_institution  \
# 0                         False                         False
# 3                         False                         False
# 7                         False                         False
# 8                         False                         False
# 10                        False                         False
# ...                         ...                           ...
# 260583                    False                         False
# 260585                    False                         False
# 260587                    False                         False
# 260590                    False                         False
# 260592                    False                         False
#
#        has_secondary_use_school has_secondary_use_industry  \
# 0                         False                      False
# 3                         False                      False
# 7                         False                      False
# 8                         False                      False
# 10                        False                      False
# ...                         ...                        ...
# 260583                    False                      False
# 260585                    False                      False
# 260587                    False                      False
# 260590                    False                      False
# 260592                    False                      False
#
#         has_secondary_use_health_post  has_secondary_use_gov_office  \
# 0                               False                         False
# 3                               False                         False
# 7                               False                         False
# 8                               False                         False
# 10                              False                         False
# ...                               ...                           ...
# 260583                          False                         False
# 260585                          False                         False
# 260587                          False                         False
# 260590                          False                         False
# 260592                          False                         False
#
#         has_secondary_use_use_police  has_secondary_use_other  \
# 0                              False                    False
# 3                              False                    False
# 7                              False                    False
# 8                              False                    False
# 10                             False                    False
# ...                              ...                      ...
# 260583                         False                    False
# 260585                         False                    False
# 260587                         False                    False
# 260590                         False                    False
# 260592                         False                    False
#
#                 age_sin_995
# 0                     30.00
# 3                     10.00
# 7                      0.00
# 8                     15.00
# 10                    20.00
# ...                     ...
# 260583                10.00
# 260585                45.00
# 260587                20.00
# 260590                 5.00
# 260592                25.00
#
# [84585 rows x 40 columns]

# %%
df_has_mas_superstruct.iloc[:,15:26]
# Out:
#         has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                               True                                 True
# 3                              False                                 True
# 7                              False                                False
# 8                              False                                 True
# 10                             False                                 True
# ...                              ...                                  ...
# 260583                          True                                 True
# 260585                         False                                 True
# 260587                         False                                 True
# 260590                         False                                False
# 260592                         False                                 True
#
#         has_superstructure_stone_flag  has_superstructure_cement_mortar_stone  \
# 0                               False                                   False
# 3                               False                                   False
# 7                               False                                   False
# 8                               False                                   False
# 10                              False                                   False
# ...                               ...                                     ...
# 260583                          False                                   False
# 260585                          False                                   False
# 260587                          False                                   False
# 260590                           True                                   False
# 260592                          False                                   False
#
#         has_superstructure_mud_mortar_brick  \
# 0                                     False
# 3                                     False
# 7                                     False
# 8                                     False
# 10                                    False
# ...                                     ...
# 260583                                False
# 260585                                False
# 260587                                False
# 260590                                False
# 260592                                False
#
#         has_superstructure_cement_mortar_brick  has_superstructure_timber  \
# 0                                        False                      False
# 3                                        False                       True
# 7                                         True                       True
# 8                                        False                       True
# 10                                       False                       True
# ...                                        ...                        ...
# 260583                                   False                       True
# 260585                                   False                       True
# 260587                                   False                       True
# 260590                                   False                       True
# 260592                                   False                       True
#
#         has_superstructure_bamboo  has_superstructure_rc_non_engineered  \
# 0                           False                                 False
# 3                            True                                 False
# 7                           False                                 False
# 8                           False                                 False
# 10                          False                                 False
# ...                           ...                                   ...
# 260583                      False                                 False
# 260585                      False                                 False
# 260587                      False                                 False
# 260590                       True                                 False
# 260592                      False                                 False
#
#         has_superstructure_rc_engineered  has_superstructure_other
# 0                                  False                     False
# 3                                  False                     False
# 7                                  False                     False
# 8                                  False                     False
# 10                                 False                     False
# ...                                  ...                       ...
# 260583                             False                     False
# 260585                             False                     False
# 260587                             False                     False
# 260590                             False                     False
# 260592                             False                     False
#
# [84585 rows x 11 columns]

# %% [markdown]
# 84585 edificios tiene más de un tipo de superstructure

# %% [markdown]
# **has_superstructure:** 84.585 edificios tiene más de un tipo de superstructure.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **legal_ownership_status**<a id='link_17'></a>

# %%
df_train_values['legal_ownership_status'].value_counts()
# Out:
# v    250939
# a      5512
# w      2677
# r      1473
# Name: legal_ownership_status, dtype: int64

# %%
df_train_values['legal_ownership_status'].value_counts(normalize='true')
# Out:
# v                   0.96
# a                   0.02
# w                   0.01
# r                   0.01
# Name: legal_ownership_status, dtype: float64

# %%
df_train_values['legal_ownership_status'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Estado legal de la tierra',color='royalblue');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('legal_ownership_status')
plt.tick_params(labelsize=10)

# %% [markdown]
# **legal_ownership_status:** hay una mayoría importante del valor **v** (96%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **count_families**<a id='link_18'></a>

# %%
df_train_values['count_families'].describe()
# Out:
# count             260,601.00
# mean                    0.98
# std                     0.42
# min                     0.00
# 25%                     1.00
# 50%                     1.00
# 75%                     1.00
# max                     9.00
# Name: count_families, dtype: float64

# %%
df_train_values['count_families'].value_counts()
# Out:
# 1    226115
# 0     20862
# 2     11294
# 3      1802
# 4       389
# 5       104
# 6        22
# 7         7
# 9         4
# 8         2
# Name: count_families, dtype: int64

# %%
df_train_values['count_families'].value_counts(normalize= True)
# Out:
# 1                   0.87
# 0                   0.08
# 2                   0.04
# 3                   0.01
# 4                   0.00
# 5                   0.00
# 6                   0.00
# 7                   0.00
# 9                   0.00
# 8                   0.00
# Name: count_families, dtype: float64

# %% [markdown]
# Porcenteje de edificios de familias.

# %%
df_train_values.loc[df_train_values['count_families']!=0,'count_families'].count()/260601
# Out:
# 0.9199465850092671

# %%
df_train_values.loc[(df_train_values['count_families']!=0)&(df_train_values['count_families']!=1),'count_families'].count()/260601
# Out:
# 0.05227915472312079

# %%
df_train_values['count_families'].value_counts().plot(kind='bar',figsize=(8,4),
                            rot=0,title='Cantidad de familias por edificio',color='m');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('count_families')
plt.tick_params(labelsize=10)

# %% [markdown]
# **count_families:** en su mayoría, la cantidad de familias por edicicio es **1** (87%). Del total de edificios, el 92% eran residencias de familias.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **has_secondary**<a id='link_19'></a>

# %%
df_has_secondary = df_train_values[[
                    'has_secondary_use',
                    'has_secondary_use_agriculture',
                    'has_secondary_use_hotel',
                    'has_secondary_use_rental',
                    'has_secondary_use_institution',
                    'has_secondary_use_school',
                    'has_secondary_use_industry',
                    'has_secondary_use_health_post',
                    'has_secondary_use_gov_office',
                    'has_secondary_use_use_police',
                    'has_secondary_use_other'   ]]

# %%
df_has_secondary.head()
# Out:
#    has_secondary_use  has_secondary_use_agriculture  has_secondary_use_hotel  \
# 0              False                          False                    False
# 1              False                          False                    False
# 2              False                          False                    False
# 3              False                          False                    False
# 4              False                          False                    False
#
#    has_secondary_use_rental  has_secondary_use_institution  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    has_secondary_use_school  has_secondary_use_industry  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    has_secondary_use_health_post  has_secondary_use_gov_office  \
# 0                          False                         False
# 1                          False                         False
# 2                          False                         False
# 3                          False                         False
# 4                          False                         False
#
#    has_secondary_use_use_police  has_secondary_use_other
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False

# %%
df_has_secondary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260601 entries, 0 to 260600
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   has_secondary_use              260601 non-null  bool
#  1   has_secondary_use_agriculture  260601 non-null  bool
#  2   has_secondary_use_hotel        260601 non-null  bool
#  3   has_secondary_use_rental       260601 non-null  bool
#  4   has_secondary_use_institution  260601 non-null  bool
#  5   has_secondary_use_school       260601 non-null  bool
#  6   has_secondary_use_industry     260601 non-null  bool
#  7   has_secondary_use_health_post  260601 non-null  bool
#  8   has_secondary_use_gov_office   260601 non-null  bool
#  9   has_secondary_use_use_police   260601 non-null  bool
#  10  has_secondary_use_other        260601 non-null  bool
# dtypes: bool(11)
# memory usage: 2.7 MB

# %%
df_has_secondary_grouped = df_has_secondary.groupby(['has_secondary_use']).sum()

# %%
df_has_secondary_grouped
# Out:
#                    has_secondary_use_agriculture  has_secondary_use_hotel  \
# has_secondary_use
# False                                       0.00                     0.00
# True                                   16,777.00                 8,763.00
#
#                    has_secondary_use_rental  has_secondary_use_institution  \
# has_secondary_use
# False                                  0.00                           0.00
# True                               2,111.00                         245.00
#
#                    has_secondary_use_school  has_secondary_use_industry  \
# has_secondary_use
# False                                  0.00                        0.00
# True                                  94.00                      279.00
#
#                    has_secondary_use_health_post  \
# has_secondary_use
# False                                       0.00
# True                                       49.00
#
#                    has_secondary_use_gov_office  has_secondary_use_use_police  \
# has_secondary_use
# False                                      0.00                          0.00
# True                                      38.00                         23.00
#
#                    has_secondary_use_other
# has_secondary_use
# False                                 0.00
# True                              1,334.00

# %%
df_has_secondary_grouped.sum(axis=1)
# Out:
# has_secondary_use
# False                   0.00
# True               29,713.00
# dtype: float64

# %%
29713/260601
# Out:
# 0.11401721405520317

# %% [markdown]
# Los edificios que no tiene uso secundario no tienen valores true.

# %%
df_has_secondary_true = df_has_secondary.loc[df_has_secondary['has_secondary_use']==1,:]

# %%
df_has_secondary_true.head()
# Out:
#     has_secondary_use  has_secondary_use_agriculture  has_secondary_use_hotel  \
# 5                True                           True                    False
# 20               True                           True                    False
# 26               True                           True                    False
# 45               True                          False                    False
# 57               True                           True                    False
#
#     has_secondary_use_rental  has_secondary_use_institution  \
# 5                      False                          False
# 20                     False                          False
# 26                     False                          False
# 45                      True                          False
# 57                     False                          False
#
#     has_secondary_use_school  has_secondary_use_industry  \
# 5                      False                       False
# 20                     False                       False
# 26                     False                       False
# 45                     False                       False
# 57                     False                       False
#
#     has_secondary_use_health_post  has_secondary_use_gov_office  \
# 5                           False                         False
# 20                          False                         False
# 26                          False                         False
# 45                          False                         False
# 57                          False                         False
#
#     has_secondary_use_use_police  has_secondary_use_other
# 5                          False                    False
# 20                         False                    False
# 26                         False                    False
# 45                         False                    False
# 57                         False                    False

# %%
df_has_secondary_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29156 entries, 5 to 260593
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   has_secondary_use              29156 non-null  bool
#  1   has_secondary_use_agriculture  29156 non-null  bool
#  2   has_secondary_use_hotel        29156 non-null  bool
#  3   has_secondary_use_rental       29156 non-null  bool
#  4   has_secondary_use_institution  29156 non-null  bool
#  5   has_secondary_use_school       29156 non-null  bool
#  6   has_secondary_use_industry     29156 non-null  bool
#  7   has_secondary_use_health_post  29156 non-null  bool
#  8   has_secondary_use_gov_office   29156 non-null  bool
#  9   has_secondary_use_use_police   29156 non-null  bool
#  10  has_secondary_use_other        29156 non-null  bool
# dtypes: bool(11)
# memory usage: 541.0 KB

# %%
del(df_has_secondary_true['has_secondary_use'])

# %%
df_has_secondary_true.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29156 entries, 5 to 260593
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   has_secondary_use_agriculture  29156 non-null  bool
#  1   has_secondary_use_hotel        29156 non-null  bool
#  2   has_secondary_use_rental       29156 non-null  bool
#  3   has_secondary_use_institution  29156 non-null  bool
#  4   has_secondary_use_school       29156 non-null  bool
#  5   has_secondary_use_industry     29156 non-null  bool
#  6   has_secondary_use_health_post  29156 non-null  bool
#  7   has_secondary_use_gov_office   29156 non-null  bool
#  8   has_secondary_use_use_police   29156 non-null  bool
#  9   has_secondary_use_other        29156 non-null  bool
# dtypes: bool(10)
# memory usage: 512.5 KB

# %%
df_has_secondary_true.sum()
# Out:
# has_secondary_use_agriculture    16777
# has_secondary_use_hotel           8763
# has_secondary_use_rental          2111
# has_secondary_use_institution      245
# has_secondary_use_school            94
# has_secondary_use_industry         279
# has_secondary_use_health_post       49
# has_secondary_use_gov_office        38
# has_secondary_use_use_police        23
# has_secondary_use_other           1334
# dtype: int64

# %%
df_has_secondary_true.sum().plot(kind='bar',figsize=(8,4),
                            rot=90,title='Cantidad de edificios por tipo de uso secundario',color='m');
ax=plt.gca()
ax.set_ylabel('Edificios');
ax.set_xlabel('has_secondary')
plt.tick_params(labelsize=10)

# %%
df_has_secondary_true['has_secondary_use_agriculture'].sum()/260601
# Out:
# 0.06437811059819418

# %%
df_has_secondary_true['has_secondary_use_hotel'].sum()/260601
# Out:
# 0.03362611808857219

# %%
df_has_secondary_true['Suma_secondary'] = df_has_secondary_true.sum(axis=1)

# %%
df_has_secondary_true['Suma_secondary'].value_counts()
# Out:
# 1    28599
# 2      557
# Name: Suma_secondary, dtype: int64

# %%
df_has_secondary_true['Suma_secondary'].value_counts().sum()
# Out:
# 29156

# %%
28599+(557*2)
# Out:
# 29713

# %% [markdown]
# **has_secondary:** 29.156 edificios tiene uso secundario y 557 tienen más de un tipo de uso.

# %% [markdown]
# #### Identificamos cuales son:

# %%
df_has_secondary['Suma_secondary']= df_has_secondary.sum(axis=1)

# %%
df_has_mas_secondary=df_train_values[(df_has_secondary['Suma_secondary'] > 2)]

# %%
df_has_mas_secondary
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 304          462457               1             679            7499
# 1408         994094               7               4           10135
# 1593         835646               7               4           10135
# 2329         678220              21             727            1576
# 3704         425504               4            1334            4279
# ...             ...             ...             ...             ...
# 256746       762884              20             190            3473
# 257939       790270              27             216            1243
# 258184       973644               1              14            1817
# 258755       952382              21             336            9977
# 260002       492007               7               4            2318
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 304                       2   40               12                  5
# 1408                      2   20                6                  6
# 1593                      3    5               16                  8
# 2329                      1    5                4                  2
# 3704                      4   10               22                 13
# ...                     ...  ...              ...                ...
# 256746                    2    5                7                  5
# 257939                    2    0                5                  6
# 258184                    2   25               11                  5
# 258755                    2   15                6                  4
# 260002                    2    0               10                  4
#
#        land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 304                         n               r  ...                   False
# 1408                        t               r  ...                   False
# 1593                        t               u  ...                   False
# 2329                        n               r  ...                   False
# 3704                        t               i  ...                    True
# ...                       ...             ...  ...                     ...
# 256746                      t               w  ...                   False
# 257939                      n               r  ...                   False
# 258184                      t               r  ...                   False
# 258755                      t               r  ...                   False
# 260002                      n               r  ...                   False
#
#        has_secondary_use_rental has_secondary_use_institution  \
# 304                       False                         False
# 1408                      False                         False
# 1593                      False                         False
# 2329                      False                         False
# 3704                      False                         False
# ...                         ...                           ...
# 256746                    False                         False
# 257939                    False                         False
# 258184                    False                         False
# 258755                    False                         False
# 260002                    False                         False
#
#        has_secondary_use_school has_secondary_use_industry  \
# 304                       False                      False
# 1408                      False                      False
# 1593                      False                      False
# 2329                      False                      False
# 3704                      False                      False
# ...                         ...                        ...
# 256746                    False                      False
# 257939                    False                      False
# 258184                    False                      False
# 258755                    False                      False
# 260002                    False                      False
#
#         has_secondary_use_health_post  has_secondary_use_gov_office  \
# 304                             False                         False
# 1408                            False                         False
# 1593                            False                         False
# 2329                            False                         False
# 3704                            False                         False
# ...                               ...                           ...
# 256746                          False                         False
# 257939                          False                         False
# 258184                          False                         False
# 258755                          False                         False
# 260002                          False                         False
#
#         has_secondary_use_use_police  has_secondary_use_other  \
# 304                            False                     True
# 1408                           False                     True
# 1593                           False                     True
# 2329                           False                     True
# 3704                           False                     True
# ...                              ...                      ...
# 256746                         False                     True
# 257939                         False                     True
# 258184                         False                     True
# 258755                         False                     True
# 260002                         False                     True
#
#                 age_sin_995
# 304                   40.00
# 1408                  20.00
# 1593                   5.00
# 2329                   5.00
# 3704                  10.00
# ...                     ...
# 256746                 5.00
# 257939                 0.00
# 258184                25.00
# 258755                15.00
# 260002                 0.00
#
# [557 rows x 40 columns]

# %%
df_has_mas_secondary.iloc[:,29:]
# Out:
#         has_secondary_use_agriculture  has_secondary_use_hotel  \
# 304                              True                    False
# 1408                             True                    False
# 1593                             True                    False
# 2329                             True                    False
# 3704                            False                     True
# ...                               ...                      ...
# 256746                           True                    False
# 257939                           True                    False
# 258184                           True                    False
# 258755                           True                    False
# 260002                           True                    False
#
#         has_secondary_use_rental  has_secondary_use_institution  \
# 304                        False                          False
# 1408                       False                          False
# 1593                       False                          False
# 2329                       False                          False
# 3704                       False                          False
# ...                          ...                            ...
# 256746                     False                          False
# 257939                     False                          False
# 258184                     False                          False
# 258755                     False                          False
# 260002                     False                          False
#
#         has_secondary_use_school  has_secondary_use_industry  \
# 304                        False                       False
# 1408                       False                       False
# 1593                       False                       False
# 2329                       False                       False
# 3704                       False                       False
# ...                          ...                         ...
# 256746                     False                       False
# 257939                     False                       False
# 258184                     False                       False
# 258755                     False                       False
# 260002                     False                       False
#
#         has_secondary_use_health_post  has_secondary_use_gov_office  \
# 304                             False                         False
# 1408                            False                         False
# 1593                            False                         False
# 2329                            False                         False
# 3704                            False                         False
# ...                               ...                           ...
# 256746                          False                         False
# 257939                          False                         False
# 258184                          False                         False
# 258755                          False                         False
# 260002                          False                         False
#
#         has_secondary_use_use_police  has_secondary_use_other  \
# 304                            False                     True
# 1408                           False                     True
# 1593                           False                     True
# 2329                           False                     True
# 3704                           False                     True
# ...                              ...                      ...
# 256746                         False                     True
# 257939                         False                     True
# 258184                         False                     True
# 258755                         False                     True
# 260002                         False                     True
#
#                 age_sin_995
# 304                   40.00
# 1408                  20.00
# 1593                   5.00
# 2329                   5.00
# 3704                  10.00
# ...                     ...
# 256746                 5.00
# 257939                 0.00
# 258184                25.00
# 258755                15.00
# 260002                 0.00
#
# [557 rows x 11 columns]

# %%
df_has_mas_secondary['has_secondary_use_other'].value_counts()
# Out:
# True    557
# Name: has_secondary_use_other, dtype: int64

# %%
df_train_values['has_secondary_use_other'].value_counts()
# Out:
# False    259267
# True       1334
# Name: has_secondary_use_other, dtype: int64

# %% [markdown]
# #### **#** Los 557 casos de dos valores true en secondary use tiene uno de esos valores en la columna has_secondary_use.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# #### **damage_grade**<a id='link_20'></a>

# %%
df_train_labels['damage_grade'].value_counts()
# Out:
# 2    148259
# 3     87218
# 1     25124
# Name: damage_grade, dtype: int64

# %%
df_train_labels['damage_grade'].value_counts(normalize='true')
# Out:
# 2                   0.57
# 3                   0.33
# 1                   0.10
# Name: damage_grade, dtype: float64

# %%
plot = df_train_labels['damage_grade'].value_counts().\
        plot.pie(figsize=(3,3),labels=('2 - Medium damage','3 - Serious damage','1 - Low damage'), colors=('#da732e', '#ff1e23', '#f1c40f' ))

#plt.labels('2 - Medium damage','3 - Serious damage','1 - Low damage')
plt.title('Grado de daño', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Grado de daño')

# %% [markdown]
# **damage_grade:** la mayoria es nivel de daño **2** (57%), mientras que la menor es **1** (10%).

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Merge de los DataFrames**<a id='link_21'></a>

# %%
df_train_values['building_id'].value_counts().sum()
# Out:
# 260601

# %%
df_train_labels['building_id'].value_counts().sum()
# Out:
# 260601

# %%
df_train_values.merge(df_train_labels)['building_id'].value_counts().sum()
# Out:
# 260601

# %% [markdown]
# #### Ambos DataFrames tiene iguales claves y coinciden 1 a 1.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Relaciones interesante entre features**<a id='link_22'></a>

# %%
ax = df_train_values.plot.scatter(x='count_families',y='age_sin_995',c='b')

ax.set_title('Relación entre cantidad de familias y antigüedad < 995', fontsize=28)
ax.set_xlabel('count_families', fontsize=24)
ax.set_ylabel('age_sin_995', fontsize=24)
plt.tick_params(labelsize=20)

# %% [markdown]
# Observamos que los edificios con más familias tienden a ser de menor antigüedad

# %%
ax = df_train_values.plot.scatter(x='area_percentage',y='age_sin_995',c='b')

ax.set_title('Relación entre area edificada y antigüedad < 995', fontsize=28)
ax.set_xlabel('area_percentage', fontsize=24)
ax.set_ylabel('age_sin_995', fontsize=24)
plt.tick_params(labelsize=20)

# %% [markdown]
# Observamos que el porcentage de area edificada crece en los edificios con menor antigüedad
