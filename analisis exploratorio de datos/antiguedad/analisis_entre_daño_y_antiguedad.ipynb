# %% [markdown]
# ### Importando las librerias

# %%
import pandas as pd
import numpy as np
import random as rd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline

plt.style.use('default')
plt.rcParams['figure.figsize'] = (20, 10)
sns.set(style="whitegrid")
pd.options.display.float_format = '{:20,.2f}'.format
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importando los datasets

# %%
df_train_values = pd.read_csv('../../datasets/train_values.csv')
df_train_labels = pd.read_csv('../../datasets/train_labels.csv')

# %% [markdown]
# ### Daños por antiguedad

# %% [markdown]
# #### Hago el filtro de los datos

# %%
df_train_values_filtered = df_train_values.loc[:, ['building_id', 'age']]

# %% [markdown]
# #### Calculo la cantidad de edificios por antiguedad

# %%
df_buildings_by_age = df_train_values_filtered\
    .groupby(['age'])\
    .count()\
    .reset_index()\
    .rename(columns={'building_id':'total_buildings_by_age'})
total_buildings_by_age = df_buildings_by_age[['total_buildings_by_age', 'age']]

# %% [markdown]
# #### Hago el merge de los datos

# %%
df_ages_and_damage = df_train_labels.merge(df_train_values_filtered).merge(df_buildings_by_age)
df_ages_and_damage
# Out:
#         building_id  damage_grade  age  total_buildings_by_age
# 0            802906             3   30                   18028
# 1            201944             3   30                   18028
# 2            433870             2   30                   18028
# 3            677028             2   30                   18028
# 4            877361             2   30                   18028
# ...             ...           ...  ...                     ...
# 260596       982608             2  170                       6
# 260597      1031144             3  170                       6
# 260598       675854             2  170                       6
# 260599       922476             2  170                       6
# 260600       854478             2  185                       1
#
# [260601 rows x 4 columns]

# %% [markdown]
# #### Hago el calculo de los porcentajes de cantidad de edificios por daño y antiguedad

# %%
df_ages_and_damage_with_percentage = df_ages_and_damage\
    .groupby(['age', 'damage_grade', 'total_buildings_by_age'])\
    .count()\
    .rename(columns = { 'building_id': 'total_buildings_by_age_and_damage' })\
    .reset_index()
df_ages_and_damage_with_percentage['percentaje'] = (df_ages_and_damage_with_percentage['total_buildings_by_age_and_damage'] * 100) / df_ages_and_damage_with_percentage['total_buildings_by_age']
df_ages_and_damage_with_percentage.iloc[0:60]
# Out:
#     age  damage_grade  total_buildings_by_age  \
# 0     0             1                   26041
# 1     0             2                   26041
# 2     0             3                   26041
# 3     5             1                   33697
# 4     5             2                   33697
# 5     5             3                   33697
# 6    10             1                   38896
# 7    10             2                   38896
# 8    10             3                   38896
# 9    15             1                   36010
# 10   15             2                   36010
# 11   15             3                   36010
# 12   20             1                   32182
# 13   20             2                   32182
# 14   20             3                   32182
# 15   25             1                   24366
# 16   25             2                   24366
# 17   25             3                   24366
# 18   30             1                   18028
# 19   30             2                   18028
# 20   30             3                   18028
# 21   35             1                   10710
# 22   35             2                   10710
# 23   35             3                   10710
# 24   40             1                   10559
# 25   40             2                   10559
# 26   40             3                   10559
# 27   45             1                    4711
# 28   45             2                    4711
# 29   45             3                    4711
# 30   50             1                    7257
# 31   50             2                    7257
# 32   50             3                    7257
# 33   55             1                    2033
# 34   55             2                    2033
# 35   55             3                    2033
# 36   60             1                    3612
# 37   60             2                    3612
# 38   60             3                    3612
# 39   65             1                    1123
# 40   65             2                    1123
# 41   65             3                    1123
# 42   70             1                    1975
# 43   70             2                    1975
# 44   70             3                    1975
# 45   75             1                     512
# 46   75             2                     512
# 47   75             3                     512
# 48   80             1                    3055
# 49   80             2                    3055
# 50   80             3                    3055
# 51   85             1                     847
# 52   85             2                     847
# 53   85             3                     847
# 54   90             1                    1085
# 55   90             2                    1085
# 56   90             3                    1085
# 57   95             1                     414
# 58   95             2                     414
# 59   95             3                     414
#
#     total_buildings_by_age_and_damage           percentaje
# 0                                7213                27.70
# 1                               12721                48.85
# 2                                6107                23.45
# 3                                5590                16.59
# 4                               19030                56.47
# 5                                9077                26.94
# 6                                4360                11.21
# 7                               22370                57.51
# 8                               12166                31.28
# 9                                2878                 7.99
# 10                              20767                57.67
# 11                              12365                34.34
# 12                               1954                 6.07
# 13                              18603                57.81
# 14                              11625                36.12
# 15                               1131                 4.64
# 16                              14073                57.76
# 17                               9162                37.60
# 18                                640                 3.55
# 19                              10444                57.93
# 20                               6944                38.52
# 21                                352                 3.29
# 22                               6246                58.32
# 23                               4112                38.39
# 24                                283                 2.68
# 25                               6088                57.66
# 26                               4188                39.66
# 27                                120                 2.55
# 28                               2802                59.48
# 29                               1789                37.97
# 30                                170                 2.34
# 31                               4156                57.27
# 32                               2931                40.39
# 33                                 45                 2.21
# 34                               1215                59.76
# 35                                773                38.02
# 36                                 76                 2.10
# 37                               2115                58.55
# 38                               1421                39.34
# 39                                 16                 1.42
# 40                                695                61.89
# 41                                412                36.69
# 42                                 32                 1.62
# 43                               1190                60.25
# 44                                753                38.13
# 45                                  8                 1.56
# 46                                317                61.91
# 47                                187                36.52
# 48                                 28                 0.92
# 49                               1759                57.58
# 50                               1268                41.51
# 51                                  7                 0.83
# 52                                551                65.05
# 53                                289                34.12
# 54                                 11                 1.01
# 55                                685                63.13
# 56                                389                35.85
# 57                                 11                 2.66
# 58                                244                58.94
# 59                                159                38.41

# %%
df_ages_and_damage_with_percentage_filtered = df_ages_and_damage_with_percentage.loc[df_ages_and_damage_with_percentage['age'] <= 100, :]
f, ax = plt.subplots(figsize=(8, 4.5))
sns.despine(f, left=True, bottom=True)
damage = [1, 2, 3]
plot = sns.scatterplot(
    x="age",
    y="percentaje",
    hue="damage_grade",
    palette={ 1: '#f1c40f', 2: '#da732e', 3: '#ff1e23' },
    data=df_ages_and_damage_with_percentage_filtered,
    ax=ax
)
plt.title('Porcentaje de daño en los ultimos 100 años de antiguedad')
plt.xlabel('age')
plt.ylabel('Porcentaje')
# Out:
# Text(0, 0.5, 'Porcentaje')

# %% [markdown]
# El análisis puede tener o bien sesgo o bien poco peso por falta de datos. Pero puede verse como al ser mas cantidad de edificios de daño nivel 2, los porcentajes siempre son mas elevados. Utilizando el gráfico y la tabla que está debajo, podemos ver que los edificios de daños nivel 1 disminuyen con muestras de la misma cantidad. Esto puede tener que ver con la calidad de la construcción o de los materiales mas robustos.
#
# Pero es un dato relevante a seguir investigando. Por otra parte, se puede ver como los edificios de nivel 2 y 3 aumentan a medida que pasa el tiempo, apoyándose en que cada vez son menos edificios con daños de nivel 1. Luego se estabiliza en el tiempo hasta tener una divergencia, que imaginamos, se debe a la falta de datos.
